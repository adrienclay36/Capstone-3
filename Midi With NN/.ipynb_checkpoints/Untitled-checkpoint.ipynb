# %%
import glob
import numpy

# %%
from music21 import converter, instrument, note, chord
notes = []
for file in glob.glob("midi/*.mid"):
    midi = converter.parse(file)
    notes_to_parse = None
    parts = instrument.partitionByInstrument(midi)
    if parts: # file has instrument parts
        notes_to_parse = parts.parts[0].recurse()
    else: # file has notes in a flat structure
        notes_to_parse = midi.flat.notes
    for element in notes_to_parse:
        if isinstance(element, note.Note):
            notes.append(str(element.pitch))
        elif isinstance(element, chord.Chord):
            notes.append('.'.join(str(n) for n in element.normalOrder))

# %%
n = note.Note(notes[2])

# %%
n.duration.type = 'half'

# %%
n.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-21-890d51ba66cc> in <module>
# ----> 1 n.show()
#
# ~\anaconda3\lib\site-packages\music21\base.py in show(self, fmt, app, **keywords)
#    2617         scClass = common.findSubConverterForFormat(regularizedConverterFormat)
#    2618         formatWriter = scClass()
# -> 2619         return formatWriter.show(self,
#    2620                                  regularizedConverterFormat,
#    2621                                  app=app,
#
# ~\anaconda3\lib\site-packages\music21\converter\subConverters.py in show(self, obj, fmt, app, subformats, **keywords)
#     377
#     378             for s in scores:
# --> 379                 fp = helperSubConverter.write(s,
#     380                                               helperFormat,
#     381                                               subformats=helperSubformats,
#
# ~\anaconda3\lib\site-packages\music21\converter\subConverters.py in write(self, obj, fmt, fp, subformats, compress, **keywords)
#     992                 and ('png' in subformats or 'pdf' in subformats)
#     993                 and not str(environLocal['musescoreDirectPNGPath']).startswith('/skip')):
# --> 994             outFp = self.runThroughMusescore(xmlFp, subformats, **keywords)
#     995         elif compress:
#     996             archiveTools.compressXML(xmlFp, deleteOriginal=True, silent=True)
#
# ~\anaconda3\lib\site-packages\music21\converter\subConverters.py in runThroughMusescore(self, fp, subformats, **keywords)
#     910                 'To create PNG files directly from MusicXML you need to download MuseScore and '
#     911                 + 'put a link to it in your .music21rc via Environment.')
# --> 912         if not musescorePath.exists():
#     913             raise SubConverterException(
#     914                 "Cannot find a path to the 'mscore' file at "
#
# ~\anaconda3\lib\pathlib.py in exists(self)
#    1386         """
#    1387         try:
# -> 1388             self.stat()
#    1389         except OSError as e:
#    1390             if not _ignore_error(e):
#
# ~\anaconda3\lib\pathlib.py in stat(self)
#    1192         os.stat() does.
#    1193         """
# -> 1194         return self._accessor.stat(self)
#    1195
#    1196     def owner(self):
#
# OSError: [WinError 123] The filename, directory name, or volume label syntax is incorrect: 'C:\\Users\\adrie\\GitHub\\Capstone3 Ideas\\Midi With NN\\C:\\Program Files\\MuseScore 3\\MuseScore.exe'
